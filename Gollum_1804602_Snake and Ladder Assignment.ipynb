# %%
#welcome message and rules

X=("Welcome, Welcome, Welcome...")
print(X)
Y1 =("I am Sanajay Mondal, the creator of this game...")
print(Y1)
Y2 =("To make this game different from traditional game you will start from 0 and if you get 6 you will roll again")
print(Y2)
Y3 =("Hope you enjoy playing this game :)")
print(Y3)

print("Player 1, Please enter your name...:")
p1=[input(),0]
print("Player 2, Please enter your name...:")
p2=[input(),0]

print(p1[0],"VS", p2[0], "Let The Game Begin...")

def game(p):

 

	print("\n",p[0]+"'s","turn:\nCurrent postion",p[1],"\nType roll to roll the dice")
	enter=input()
	while(enter!="roll"):
		print("Try Again!")
		enter=input()
	x=random.randint(1, 6)
	print("Dice Rolled to:",x)
	if p[1]+x<=100:
		p[1]+=x
	if x==6:
		print("Now",p[0]+"'s","postion is",p[1])
		while(x==6):
			if p[1] in snakes:
				print("HISSS, Snake Bites, go down",p[0])
				p[1]=snakes[p[1]]
				break
			if p[1] in ladders:
				print(p[0],"Hurry up, climb the ladder")
				p[1]=ladders[p[1]]
				break
			print("Congratulation,roll again!!!")
			enter=input()
			while(enter!="roll"):
				print("Please Try Again!!!")
				enter=input()
			x=random.randint(1, 6)
			print("Dice:",x)
			if p[1]+x<=100:
				p[1]+=x
		print("Now",p[0]+"'s","postion is",p[1])
	else:
		if p[1] in snakes:
			print("HISSS, Snake Bites, go down",p[0])
			p[1]=snakes[p[1]]
		if p[1] in ladders:
			print(p[0],"Hurry up, climb the ladder")
			p[1]=ladders[p[1]]
		print("Now",p[0]+"'s","postion is",p[1])
  
  

snakes={17 : 7, 54 : 34, 62 : 19, 98 : 79}
ladders={3 : 38, 24 : 33, 42 : 93, 72 : 84}
import random
while(p1[1]!=100 and p2[1]!=100):
	game(p1)
	if p1[1]==100:
		break
	game(p2)
if p1[1]==100:
	print("\n",p1[0],"WInner Winner Chicken Dinner!!!")
else:
	print("\n",p2[0],"WInner Winner Chicken Dinner!!!")
